# %% [markdown]
# # Youtube API 每日更新影片數據

# %%
import requests
import json
import pandas as pd
import datetime as dt

# %%
# 每API每日上限100萬筆，因此需要分批抓取
# 預估220萬筆，分四批抓取，0-80, 80-160, 160-450, 450-1000
apikey = 'AIzaSyC1MJl-k7L0RRTpFBh7NWTbR169THIHxWA'  #80
m = 0
n = 80

# apikey = 'AIzaSyDbWc2DPjRnJY-kaSZUbChbfZ38QIuqa-0'  #160
# m = 80
# n = 160

# apikey = 'AIzaSyAap0US19fDa3wDaON4Yu7FeCvtc_C8yAI'  #450
# m = 160 
# n = 450

# apikey = 'AIzaSyA0Coldmird4u6I14d0QRHE_d-4DBrlRPU'  #999
# m = 450
# n = 1000

# %%
list_id = pd.DataFrame.from_csv('ytid_tw.csv', header=0, index_col=0)
channel_list = list_id['ID'][m:n]               # 分四批抓取，0-80, 80-160, 160-450, 450-1000

# %%
# 影片播放清單 playlist
url = 'https://www.googleapis.com/youtube/v3/playlists'
parts = 'snippet,contentDetails'

def get_playlist(cid):
    parameters = {
        'part': parts,
        'channelId': cid,
        'key': apikey,
        'maxResults':50    #0-50
    }

    # 先取出頻道所有playlist
    page = requests.request(method='get', url=url, params=parameters)
    js = json.loads(page.text)
    
    if not js.get('items'):
        return
    else:
        
        playlist = []

        for i in range(len(js['items'])) :
            playlist.append( [js['items'][i]['id'],                  # playlist id
                        js['items'][i]['snippet']['title'],     # playlist name
                        js['items'][i]['snippet']['channelTitle']     # channel title
                       ] )

        return playlist   #回傳多行array

# %%
df_playlist = pd.DataFrame()

for cid in channel_list:
    df_playlist = df_playlist.append(get_playlist(cid), ignore_index=True)  # 將多行array加到DataFrame，不要[]
# Out:
# UCYlR7sckITRRtwF-mRdqu8A
# UC4Mos7L9fkCVhCXBERnWTmQ
# UCYWcAVOwYTWpUanVthcZmaQ
# UCKEshOzNkXEAtt6h1zS0A6Q
# UCh2J61MN8OhThjMBN7Ho44Q
# UCI4R54VuE039uUyU_wL0GsA
# UCeLNrHzggGEZnmgCZXDZ_4w
# UCNBgquLyP2zOAJURDJAUYTA
# UCRNNHJdQQuTc1PwdphkD68g
# UCAqtJ9Us6KjD67j7zPV2xUA
# UCCPfI2vQnAc3ZxWpmwDyM1A
# UCeDhoBQvd33wtNXpQL-RnSw
# UCBDPzPvkdes1gyJ4xS0yBCA
# UCO3r3FllELijijdytnR43NA
# UCZn_4OK5Y8FfxajCaX4AZ_Q
# UCiuMb0mv6XtwQjQQ95LnJHw
# UCHpwj_AsgvrlqSyUsp2rw8Q
# UCMMxDfekjyeqHHN9bp1NcYA
# UCI1RTYd_EM0v5A-lVVwQgvw
# UC156sJZHpO2KMm5TotIWM2w
# UCZrbiZOvQ8sZH5ycwEtyptg
# UCYChWT3fQWMCS56CORtkiTQ
# UCi7eKRJZvxMhwhiWyARZtjg
# UCyGUGDvCeXapYlu8FYZHFag
# UCeps1H_ch0qDwH8shnRkdhw
# UCP3PORZEl5R27Ax_xjEsqcg
# UCFs3BgRGaCnPXQee6KK-Orw
# UCSgMSX5EARCyzA1P6vWCcpA
# UCl3MRIpEjC4v2wWdsk2Mabw
# UCT4pwSqwC2_hA9Mxp1JW-Zw
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-0d4420f3e6a5> in <module>()
#       3 for cid in channel_list:
#       4     print(cid)
# ----> 5     df_playlist = df_playlist.append(get_playlist(cid), ignore_index=True)  # 將多行array加到DataFrame，不要[]
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity)
#    4632             if not self.columns.equals(combined_columns):
#    4633                 self = self.reindex(columns=combined_columns)
# -> 4634         elif isinstance(other, list) and not isinstance(other[0], DataFrame):
#    4635             other = DataFrame(other)
#    4636             if (self.columns.get_indexer(other.columns) >= 0).all():
#
# IndexError: list index out of range

# %%
# 將playlist輸出成DataFrame
df_playlist = df_playlist.rename(columns={0:'playlist_id',1:'playlist_name', 2:'channel_title'})
df_playlist
# Out:
#                             playlist_id  \
# 0    PLH_jrUYcerbq6i5GhUAc09luV_TxkL6ds
# 1    PLH_jrUYcerbq4gSeIqToKiXVKkYF98e1s
# 2    PLH_jrUYcerboisUFCoycR6J5ZfS5ZTeeG
# 3    PLH_jrUYcerbrzEdAXwYywGSSpMX3enEj4
# 4    PLH_jrUYcerbpEskKFHGnQnubZMof65TK_
# 5    PLH_jrUYcerbpyC6ug8zAlNSvQb4vHsXSF
# 6    PLH_jrUYcerbovV1ShvgRZo79JCieBGSsg
# 7    PLH_jrUYcerbq5PHloSCSYYYb1z24V1GZk
# 8    PLH_jrUYcerbo6dvR3RVtZMjnKIm-yQEBC
# 9    PLH_jrUYcerbqtz_AwaG0b4p0H5mPiNjRt
# 10   PLH_jrUYcerboMJVE2S-QKruOMHmiBvpFF
# 11   PLH_jrUYcerboxKa10ZchPYtWTTjO3CnMX
# 12   PLH_jrUYcerbqsSVon5BXoNiYUs9GZHTZD
# 13   PLH_jrUYcerbopDayp_GAhDuz3zmr35kJT
# 14   PLH_jrUYcerbr4WbClR1rTAE_1vs5cNcg1
# 15   PLH_jrUYcerbrRxyNmjHxp36q3HUS7Mywx
# 16   PLH_jrUYcerbrxb7xyHKW4Y-Xot2uEYnv3
# 17   PLH_jrUYcerbotcnNLx87H3iYyEMHi9Nln
# 18   PLH_jrUYcerbpBQI8uMMlkhDsLWuw_M7u-
# 19   PLH_jrUYcerbpFwc3vCQ5ZvOdovmupzO0G
# 20   PLH_jrUYcerbo3bKdLrTT6ldtQGW_7t_1a
# 21   PLH_jrUYcerbptnxynRbdJMMVTLJtO7P0t
# 22                   PL30E65DA427C63FCD
# 23                   PL1834DC6896213FE0
# 24                   PLB221005D895FF472
# 25                   PLA5CA6B3BCA74FFDF
# 26                   PL60AFEBE246B605D0
# 27   PLf5SPN8zFp6Gb98nAvUNii-ieMrYtsEkL
# 28   PLf5SPN8zFp6ES8sT9zvUp3jCNf3zHNlX1
# 29   PLf5SPN8zFp6GCkBBBNl7-sH0qq6ge73Aj
# ..                                  ...
# 362  PLgFC_SXvt6Lmwh7-XyGFOf_81septXy80
# 363  PLgFC_SXvt6Lk36oHLIi1QF3efj6DLIsZn
# 364  PLgFC_SXvt6LkAVnsBX90iUkSu3-P0Ezfv
# 365  PLgFC_SXvt6Lnjxxb2bn4wxxbVY9RA2FEB
# 366  PLgFC_SXvt6LkCMDJ67wy77NvHchb9sUUj
# 367  PLgFC_SXvt6Ln8rNn-vc7zmMlSRCtJm-0L
# 368  PLgFC_SXvt6LmwjhH5Jq7UvICbnS3NNQwH
# 369  PLgFC_SXvt6LkKwjwR9IhmTm-t6_dndurJ
# 370  PLgFC_SXvt6Ln-rRNECg7-Ov9Dx_ROsJtw
# 371  PLgFC_SXvt6LnWsxfNWOC0RtC06joRl0Qw
# 372  PLgFC_SXvt6LnOQ3eM-C6dG7j8UcX351wv
# 373  PLgFC_SXvt6Lmb2BQ7A99AgRndjzuSh6Zi
# 374  PLgFC_SXvt6LksCL67wHQLi_san5Fk9hXt
# 375  PLgFC_SXvt6LmFdro8ok5c6Wpf5VqjoRKl
# 376  PLgFC_SXvt6LkqwLF_Opp7HAWndBJ_HAHv
# 377  PLgFC_SXvt6LkHL9TYspe3xeINn26AMYRu
# 378  PLgFC_SXvt6LmTr2NXBp-4-SUsk-eOnP-L
# 379  PLgFC_SXvt6LmsBaPJupeTACMWS0jw_6re
# 380  PLgFC_SXvt6LnaeH6Z9wJ8MDQnUKIr5m2S
# 381  PLgFC_SXvt6LlDj8gGoHRhU0AtVxHpNknr
# 382  PLgFC_SXvt6LmByjzSBtO1aD1W9J5D3ppg
# 383  PLgFC_SXvt6LlFiB1BTPuZCnZWX8EVjc9x
# 384  PLgFC_SXvt6LnqJtE_I8qwhGFfyX-XwpWB
# 385  PLgFC_SXvt6Ll6e3XcAc92_wLO_JUUffxS
# 386  PLgFC_SXvt6Lnz6oPtlYZMuglc25nhy_Zu
# 387  PLgFC_SXvt6Lmkks32yM_6l-Eb6KMdgBom
# 388  PLgFC_SXvt6LkYvsRdMGQunFCL4OE8CTFj
# 389  PLgFC_SXvt6LmToc3GnDOkPDrTed91_SLX
# 390  PLgFC_SXvt6LlRaznw--e4-OOBkE3P2--4
# 391  PLgFC_SXvt6LnCgyvAFpi4s_bR9x-yXv3E
#
#                                          playlist_name    channel_title
# 0                                             【群人採訪系列】         TGOP 這群人
# 1                                              【偽廣告系列】         TGOP 這群人
# 2                                             【瘋狂職人系列】         TGOP 這群人
# 3                                              【大暴走系列】         TGOP 這群人
# 4                                             展榮展瑞專屬頻道         TGOP 這群人
# 5                          【超瞎翻唱系列】這群人『超蝦翻唱2之情歌寶典』英文原曲         TGOP 這群人
# 6                               【三個人 Three People】歌曲系列         TGOP 這群人
# 7                                【超瞎翻唱系列】這群人【超瞎翻唱】英文原曲         TGOP 這群人
# 8                                       這群人愛娛樂【雙胞胎新鮮試】         TGOP 這群人
# 9                                                 新聞報導         TGOP 這群人
# 10                                      這群人愛娛樂 【來都給你講】         TGOP 這群人
# 11                                        這群人私生活【群人花絮】         TGOP 這群人
# 12                                        【如果你有這種朋友系列】         TGOP 這群人
# 13                                      【這群人TGOP音樂原創區】         TGOP 這群人
# 14                            【時事惡搞】無聊新聞/群人新聞系列/群人採訪系列         TGOP 這群人
# 15                                           【偽八點檔預告片】         TGOP 這群人
# 16                                        【微影集】靈洞：魂飛破傘         TGOP 這群人
# 17                                                幕後花絮         TGOP 這群人
# 18                                        【時事惡搞】群人新聞系列         TGOP 這群人
# 19                                         【相關新聞報導】這群人         TGOP 這群人
# 20                                           【假單曲MV系列】         TGOP 這群人
# 21                                            【經典語錄系列】         TGOP 這群人
# 22                                          【偽電影預告片系列】         TGOP 這群人
# 23                                            【群人迷你劇場】         TGOP 這群人
# 24                                              所有搞笑短片         TGOP 這群人
# 25                                                競賽作品         TGOP 這群人
# 26                          【相關出征】這群人(對外演出廣告、短片、節目、通告)         TGOP 這群人
# 27   五月天 LIFE [ 人生無限公司 ] 歐洲巡迴演唱會 2018/3/2 Paris、3/4...     相信音樂BinMusic
# 28                                  東森戲劇【我和我的四個男人】原聲EP     相信音樂BinMusic
# 29   2018.01.27 ONE OK ROCK [ AMBITIONS ASIA TOUR 2...     相信音樂BinMusic
# ..                                                 ...              ...
# 362             冼佩瑾 Celeste Syn「為什麼要乖 Why」首張創作專輯 Album  杰威爾音樂 JVR Music
# 363                 「春梅 HARU」電視原聲帶 Original Soundtrack  杰威爾音樂 JVR Music
# 364                             ♬ 杰威爾精選 JVR Highlights  杰威爾音樂 JVR Music
# 365             ♬ 周杰倫 詞曲精選 ★ Songs Written by Jay Chou  杰威爾音樂 JVR Music
# 366            袁詠琳 Cindy Yen「Fight For Love」創作專輯 Album  杰威爾音樂 JVR Music
# 367   ♬ 周杰倫x方文山 精選創作 Jay Chou x Vincent Fang Creations  杰威爾音樂 JVR Music
# 368        周杰倫 Jay Chou「哎呦, 不錯哦 Aiyo, Not Bad」專輯 Album  杰威爾音樂 JVR Music
# 369                   邱凱偉Darren【幕後花絮】Behind-the-scenes  杰威爾音樂 JVR Music
# 370                   袁詠琳Cindy【廣告代言】 Endorsements / CF  杰威爾音樂 JVR Music
# 371  ✇ 袁詠琳 Cindy Yen【2 BE DIFFERENT】幕後特輯 Behind The...  杰威爾音樂 JVR Music
# 372                         袁詠琳 Cindy Yen【單曲作品】Singles  杰威爾音樂 JVR Music
# 373                袁詠琳 Cindy Yen【獻給袁寶】To Fans of Cindy  杰威爾音樂 JVR Music
# 374                袁詠琳 Cindy Yen【FLY TONIGHT】單曲 Single  杰威爾音樂 JVR Music
# 375                           ♬ 袁詠琳 Cindy Yen【袁詠琳同名專輯】  杰威爾音樂 JVR Music
# 376            ★ 周杰倫 精選花絮 ★ Jay Chou behind-the-scenes  杰威爾音樂 JVR Music
# 377                    ♬ 袁詠琳 Cindy Yen【2 Be Different】  杰威爾音樂 JVR Music
# 378                                ★ 方文山導演電影【聽見下雨的聲音】★  杰威爾音樂 JVR Music
# 379               ♬ 周杰倫【依然范特西】Jay Chou "STILL FANTACY"  杰威爾音樂 JVR Music
# 380          ♬ 周杰倫【十一月的蕭邦】Jay Chou "NOVEMBER'S CHOPIN"  杰威爾音樂 JVR Music
# 381         ♬ 周杰倫【七里香】Jay Chou "COMMON JASMINE ORANGE"  杰威爾音樂 JVR Music
# 382                   ♬ 周杰倫【葉惠美】Jay Chou "YEH HUI MEI"  杰威爾音樂 JVR Music
# 383                    ♬ 周杰倫【我很忙】Jay Chou "ON THE RUN"  杰威爾音樂 JVR Music
# 384                     ♬ 周杰倫【魔杰座】Jay Chou "CAPRICORN"  杰威爾音樂 JVR Music
# 385                ★ 周杰倫電影【天台】Jay Chou movie "ROOFTOP"  杰威爾音樂 JVR Music
# 386                      ♬ 周杰倫【十二新作】Jay Chou "OPUS 12"  杰威爾音樂 JVR Music
# 387             ♬ 周杰倫【八度空間】Jay Chou "EIGHTH DIMENSION"  杰威爾音樂 JVR Music
# 388                       ♬ 周杰倫【范特西】Jay Chou "FANTACY"  杰威爾音樂 JVR Music
# 389                       ♬ 周杰倫【跨時代】Jay Chou "THE ERA"  杰威爾音樂 JVR Music
# 390             ♬ 周杰倫【驚嘆號】Jay Chou "EXCLAMATION POINT"  杰威爾音樂 JVR Music
# 391                     ♬ 周杰倫【同名專輯】Jay Chou "JAY CHOU"  杰威爾音樂 JVR Music
#
# [392 rows x 3 columns]

# %%
# 將資料輸出成csv檔案
today = str(dt.datetime.today()).split()[0]
filename = 'playlist_%s_%d-%d.csv' % (today, m, n)
df_playlist.to_csv(filename)

# %%
#### 修正additional

df_playlist = pd.DataFrame.from_csv('.csv', header=0, index_col=0)
df_playlist = df_playlist['playlist_id'][1991:]

# %%
# 影片ID，自playlist取出
videoid = []

def get_videoid(plid):
    url = 'https://www.googleapis.com/youtube/v3/playlistItems'
    parameters = {
        'part':'snippet,contentDetails',
        'playlistId':plid,   #這邊放playlist
        'key': apikey,
        'maxResults':50    #0-50, default 25
    }

    page = requests.request(method='get', url=url, params=parameters)
    js = json.loads(page.text)
    
    if not js.get('items'):
        print('not found')
        return
    else:
        js1 = js['items']
        for i in range(len(js1)):
            videoid.append(js1[i]['contentDetails']['videoId'])

# %%
# 取playlist id

for i in range(len(df_playlist['playlist_id'])):
    get_videoid(df_playlist['playlist_id'][i])
    
videoid  #影片id的array
# Out:
# not found
# ['W7U-2HQ6waw',
#  'kPtxfQhA2Uo',
#  'B4I2F6AT-nA',
#  'rOBXXnZmnls',
#  '3BTyNHBWrL4',
#  'k410JeMj0oU',
#  'Bld1491U76s',
#  'jdAve04_WVk',
#  'NVLYdkJRUR0',
#  'LmiIfOIeHRs',
#  'HnB7pJa78yU',
#  'TUqObQCbU_g',
#  '21DbYMPTtW0',
#  'sZLMIR5HigM',
#  'cs4kfLTlrOo',
#  '5ZQUuER667w',
#  'j0yxPWsVk5s',
#  'sxmjFq7PDK4',
#  'PqylViIJyNs',
#  'dwmC8iNQwcQ',
#  '3ZBZRSdfjoU',
#  'a5_3uRFJGI0',
#  't5wM5M0cNDs',
#  'Azrht96HLP4',
#  '_5EgmVM8XuI',
#  '-Thyn168CLw',
#  'WipnNvawCVY',
#  'cG-LtPUytwE',
#  'YaQB1xpEZYQ',
#  'QV1xIukBxlQ',
#  'Ub-K4Xx3O6w',
#  '2zmvlWqfY80',
#  'B2sieu506HQ',
#  '6MKOUsLayk8',
#  'IFxE3koBzxg',
#  'jIY7_7Hueag',
#  'xBzdbHO5ZUg',
#  'xBzdbHO5ZUg',
#  'CsdPf3G0Q-E',
#  'n1wBUcJZASg',
#  'B7CZC7Lbnbk',
#  'MVIGM8P9I4A',
#  'dXOhAZtBuTg',
#  '3xTvzNX6zBU',
#  'kJvptnwNsl4',
#  'dKlWsFeq_Q8',
#  'eRxDAY4-SOA',
#  'OC-T1kBgotY',
#  'FYRCOMEZv8k',
#  'aQ3Pzdevgsk',
#  '7DEzslOAoEo',
#  'ZL5c67dZtK4',
#  'UOt2PlYvu24',
#  'Mk4eryi1758',
#  '3GVwFDElFig',
#  'e4UPeO5DdJc',
#  'Gpst5m5ccuM',
#  'fo4pIPuSzKM',
#  'VbfpW0pbvaU',
#  '9WbCfHutDSE',
#  'lp-EO5I60KA',
#  'o_1aF54DO60',
#  '8UVNT4wvIGY',
#  '3AtDnEC4zak',
#  '09R8_2nJtjg',
#  '9b8erWuBA44',
#  'eAfyFTzZDMM',
#  'Lo3lxS-6joY',
#  'SXiSVQZLje8',
#  'ZSM3w1v-A_Y',
#  'C_3d6GntKbk',
#  'My2FRPA3Gf8',
#  'VA770wpLX-Q',
#  'eJSik6ejkr0',
#  'WBKnpyoFEBo',
#  'IxszlJppRQI',
#  'DUT5rEU6pqM',
#  'MyeN5h9nLas',
#  '8WYHDfJDPDc',
#  '4fndeDfaWCg',
#  'QrOe2h9RtWI',
#  'ulOb9gIGGd0',
#  'FrLequ6dUdM',
#  '7F37r50VUTQ',
#  'IvN5h9BE444',
#  'PT2_F-1esPk',
#  'jsbeemdD2rQ',
#  '2vjPBrBU-TM',
#  'dXOhAZtBuTg',
#  'P76Du-xHIM8',
#  '71uHBFo87C8',
#  'RIDjwDqO4S8',
#  'dXOhAZtBuTg',
#  'e6rmTHmQr-E',
#  'ORvaVk4u3Ck',
#  'n1wBUcJZASg',
#  '-Thyn168CLw',
#  'Hy8kORiO-_M',
#  'GbZ7XfvxJMk',
#  'g_AW-Zcp_LA',
#  'NVHk5IQexNo',
#  'YaQB1xpEZYQ',
#  'Sfiznv3voZE',
#  'Sfiznv3voZE',
#  'pGAK8dA1FrE',
#  'Gpst5m5ccuM',
#  'e4UPeO5DdJc',
#  'MW4ljt-_kyU',
#  'gt7PxEumMJ0',
#  'JPIhUaONiLU',
#  'bMpFmHSgC4Q',
#  'UtF6Jej8yb4',
#  'AJtDXIazrMo',
#  'ktvTqknDobU',
#  'CevxZvSJLk8',
#  'Jwgf3wmiA04',
#  'uxpDa-c-4Mc',
#  '7PCkvCPvDXk',
#  '5GL9JoH4Sws',
#  'y6Sxv-sUYtM',
#  'uo35R9zQsAI',
#  'nfWlot6h_JM',
#  'vjW8wmF5VWc',
#  'jGflUbPQfW8',
#  '0HDdjwpPM3Y',
#  'UpsKGvPjAgw',
#  'XhgJCO70yog',
#  '0J3vgcE5i2o',
#  'XgJFqVvb2Ws',
#  'kYtGl1dX5qI',
#  'g5qU7p7yOY8',
#  'M11SvDtPBhA',
#  'OPf0YbXqDm0',
#  'NOubzHCUt48',
#  'XNtTEibFvlQ',
#  'niqrrmev4mA',
#  '2zNSgSzhBfM',
#  'CvBfHwUxHIk',
#  'PLolag3YSYU',
#  '4GuqB1BQVr4',
#  'lWA2pjMjpBs',
#  '4JipHEz53sU',
#  '2lqUGIP6kOs',
#  'UOt2PlYvu24',
#  'OC-T1kBgotY',
#  '3GVwFDElFig',
#  'aQ3Pzdevgsk',
#  'FYRCOMEZv8k',
#  'QVADhUkdWbo',
#  'DlrAuKUFLRk',
#  's6cl3FySTaY',
#  'NYt2BaiyQ9s',
#  'NYt2BaiyQ9s',
#  'EHF79qPKjk0',
#  'h5xMZi1XeQg',
#  'Mw2Csr9bjdI',
#  '3FTiQyItuZY',
#  'Mhw1y_ssGuI',
#  'vUxH4wwrFMI',
#  'GLiY4VaBrxk',
#  'kFDR1WY_6UE',
#  'wPJp4By3hqM',
#  'eBldL8jNjZU',
#  'yG8QjSRpaOg',
#  'Peu8nQMbY4g',
#  '_VoBE9jJ59E',
#  'bY2AeNq1yEA',
#  'EL5sAhgY80g',
#  '3Idgfs6PO1A',
#  'Ch149ts-iDs',
#  'uDfMSACzcek',
#  'AGc8ueVoYPI',
#  'Vw8ezFzotEs',
#  'D5qT8F8bx_0',
#  '_F7EpBh7vyM',
#  'LZJU0Rgqpjc',
#  'RDqutpu4DH8',
#  'mjm4EwzG2L8',
#  '3Jcx09rdKp0',
#  'g6j-ZyF92wA',
#  'Vok8pD8Pgpo',
#  'W7U-2HQ6waw',
#  'kPtxfQhA2Uo',
#  'B4I2F6AT-nA',
#  'krG9wlTagaA',
#  'rOBXXnZmnls',
#  'TWc8BAy4IZo',
#  '2B22SWkXC7k',
#  'Ii8xc14fqzI',
#  'mDpZNbA_zC8',
#  '6dzmK3C_-vo',
#  'JYYMffQcphw',
#  'VrgnFFDoVH0',
#  'EAhdwi64Xto',
#  'jnzVLMS7AUE',
#  '-5rd_GONWH0',
#  'R_gkPBTozCM',
#  'qScDl4JNwyM',
#  '3YXLJrdJuxA',
#  'onTd64_PJmw',
#  'IFS1lxzsuzA',
#  'L7jExcCg7gs',
#  '14qzCSOB3Rs',
#  'mDpZNbA_zC8',
#  'Ii8xc14fqzI',
#  '6dzmK3C_-vo',
#  'EAhdwi64Xto',
#  'VrgnFFDoVH0',
#  'JYYMffQcphw',
#  'TWc8BAy4IZo',
#  'NYt2BaiyQ9s',
#  'QVADhUkdWbo',
#  'TTOwl8UG2Xc',
#  'c4t8V7EE3ac',
#  'ngtzP2jpQOY',
#  'TgupGcY8Gdk',
#  'NNetA9xKInc',
#  'rHdznJRPoYw',
#  '27jgaerQDG4',
#  '7e3ZjaXcvYA',
#  'XBBLij7XHug',
#  'W8sH3UCV_R4',
#  'xuyuP92EMZY',
#  'Rpgd_mRXTzc',
#  'nSyw_yUHIAc',
#  'YUzy8bJmDmg',
#  '_kkFZ3JKsaU',
#  '8JWqI9XQKO8',
#  'nBpMbX-Qq_A',
#  '5My0N-SWsZU',
#  '-BQivMqgGZg',
#  '-rtehKJrdck',
#  'Qf_kEELSSKY',
#  'NYXb5LT8rIg',
#  'XAlvOCEq_rg',
#  'W6obwGvFT3g',
#  'mayRuANk51w',
#  'OIfALs_4USo',
#  'u17YJTvS2DY',
#  'aaPY3FJIoDs',
#  'qzlOutZd7ao',
#  '54E0fALTFKA',
#  '-1Ci4WwYQSk',
#  'QQc8GtEcOuE',
#  '9LDjnKnGAMM',
#  '-reqZIE_DSg',
#  'k2eeqrt5if8',
#  'yAk1EA1mUpk',
#  'XT70GArqITo',
#  '1wp3YexJSTM',
#  'mOYZy-U4RCE',
#  'JlRX3nap_nE',
#  '6BmOZjyFifg',
#  'Wm8SfJjatg8',
#  'tEeyUnz8fAk',
#  'aY1wsqPUgRc',
#  'XpNCTZLL5K8',
#  'J7289X5A2BU',
#  'BLJ6NJ_LVKA',
#  'HP4kv0-Xqks',
#  '4u5r9YA9cqc',
#  'SY-_5BaSAr0',
#  'uXwgcJ2huFw',
#  'DLFPqJedFuw',
#  '2S_jzkdlzBc',
#  'j0yxPWsVk5s',
#  'MjFCRhNmuiE',
#  'Gpst5m5ccuM',
#  'hi07uBDPmC0',
#  'OIktvDwdBP0',
#  'eXXTxTedY2w',
#  '2S_jzkdlzBc',
#  'sIUreDRRc7w',
#  'ip4iWGFWWYU',
#  'KUfGRlBrWS8',
#  '7L2kyRURIK4',
#  'IFS1lxzsuzA',
#  '2B22SWkXC7k',
#  'onTd64_PJmw',
#  'E_yzd2Liroc',
#  'J7289X5A2BU',
#  '-reqZIE_DSg',
#  'aY1wsqPUgRc',
#  'Rpgd_mRXTzc',
#  '9LDjnKnGAMM',
#  'h6R7nbTjrLY',
#  '-V4wuvj4G88',
#  'BeDXCiAH1i0',
#  '14qzCSOB3Rs',
#  'xGsZBZghVZM',
#  'bc6uMbEgnho',
#  'f9QuG2PzS5Y',
#  'mjm4EwzG2L8',
#  'RDqutpu4DH8',
#  'LZJU0Rgqpjc',
#  '_F7EpBh7vyM',
#  'D5qT8F8bx_0',
#  'Vw8ezFzotEs',
#  'sZLMIR5HigM',
#  'cs4kfLTlrOo',
#  'p5AKn3sIh2Y',
#  'NYXb5LT8rIg',
#  'Qf_kEELSSKY',
#  'rvmNuAI6uug',
#  'XAlvOCEq_rg',
#  'DLFPqJedFuw',
#  'ZRIs-oN8HHY',
#  '0m_ZjYQEd40',
#  'AGc8ueVoYPI',
#  'g6j-ZyF92wA',
#  '3Jcx09rdKp0',
#  'mayRuANk51w',
#  'XSnjYml5aZY',
#  'W6obwGvFT3g',
#  'TUqObQCbU_g',
#  'ip4iWGFWWYU',
#  'HP4kv0-Xqks',
#  'eXXTxTedY2w',
#  'OIktvDwdBP0',
#  '7At3cIw-5Xs',
#  'PlUa6ErKf20',
#  'WcxmiCoOJg4',
#  '57Znia-w4ms',
#  'EewTLtzJdXg',
#  'V18o2HlI0lE',
#  '97qXAgWce6Y',
#  '_zOrGvMcZng',
#  'A-1h7AMEBes',
#  'RLsFZ6Vhj9s',
#  'TK7XIgszMNE',
#  '0V7U3XQCaEM',
#  'T6jFrZqz9X8',
#  'hlvmP-gPIpU',
#  'uDhE_p-kTvg',
#  'POBz3hynkjs',
#  'NYt2BaiyQ9s',
#  '21HkaKHfDx8',
#  '4fkUQsCuDMc',
#  'xGsZBZghVZM',
#  'Zmp-cksSX5g',
#  '_5rtXyciqEE',
#  'B-vV_8EY76E',
#  'kd8AY7Kd7VU',
#  'OtVJhlGwrCo',
#  'wJ59hdM6bc0',
#  '-vxZRn286Fk',
#  'j2slUcQtt8U',
#  'JnTFQYwfLaM',
#  'rUzAL24_7Ec',
#  'fschVoN9C9c',
#  'XM0owDwmLkk',
#  '_Ovk4F8uQuM',
#  'rN1rwI9Snm8',
#  'nsElYpZW6Jg',
#  'U2H7to4Y2C8',
#  'pNbJP4Y5hJg',
#  'tsAOa2r6z_Y',
#  'IUwIqYoGUws',
#  'h7EWvlD2AD0',
#  'KgpyWyYy-V8',
#  'S7avjGeFxzw',
#  'HzMHdX8gn2A',
#  'HNJ5A5cJl_c',
#  'ujbNmrOy01k',
#  'XS8hs1RszpQ',
#  'ot5xoDgJvjQ',
#  'pT5M-hiD8QE',
#  '2X0f3fuGDHM',
#  's5Xl5MXboas',
#  'H91wbPSBMGo',
#  'vbhY5Wd0rhw',
#  '-hU1O3bG1eo',
#  'u0bcXim2m4M',
#  'P1DojnvnQAs',
#  'lUCa4e5Mkrc',
#  'HWkXRr5WAs0',
#  '-JPWBtz0Y0U',
#  '5FoP6YNoxTA',
#  'Hh9yZWeTmVM',
#  'xGbxsiBZGPI',
#  '6YZlFdTIdzM',
#  'UjZqcDYbvAE',
#  'tcBBNB5JTOQ',
#  'JWSRqWpWPzE',
#  'WgjgACnHuWQ',
#  'x9v8aNl6Aps',
#  'C-xF2MAFw5s',
#  'Y_tUf_-Xz44',
#  '2xq0l0sTOCw',
#  'MZxw67p0Nj4',
#  '2pdbjnp9GlI',
#  'HJjQ-D5AANY',
#  'b7gtHGP5_kA',
#  'IU95ujK9nG8',
#  'KoyH7Ws6wrk',
#  'FgYgvfdDqxo',
#  '97rnLbqa_aI',
#  'i6MnwQeMgdY',
#  'fRSiggOKAL4',
#  'tT8uQP3puxM',
#  '1M3JvH3jwE8',
#  'QMd7lp5n5qU',
#  '6k9DNRM2wKo',
#  'E1xrBs_BZgs',
#  '3LmjBbP-e8U',
#  'YKiMrg6rgYQ',
#  'HxIct0i-CcA',
#  'pd3eV-SG23E',
#  'eZMH6Mo0f9A',
#  'Fn7NLWHJw4s',
#  't5EiR5txpJU',
#  '5SGfaMUfAhc',
#  '6k9DNRM2wKo',
#  '-hU1O3bG1eo',
#  'u0bcXim2m4M',
#  'P1DojnvnQAs',
#  'lUCa4e5Mkrc',
#  'EzHAkXzCny4',
#  'J9KCc0ht_lY',
#  'd3IQo9NgTtI',
#  '7wvNwOPprBE',
#  '8PN6EirwiQI',
#  'CqlnZuXQpy8',
#  'sGsCc34EgeI',
#  'X08lyEBG11g',
#  'BcY75hwb_Ls',
#  '01T6rQVIdss',
#  'yybtW6tSLeM',
#  'lA3uw51k4y8',
#  'PWvGSuNvDtw',
#  'fgWLAYFv9G0',
#  '6dyiTf9kHDg',
#  'qX2GsMj7154',
#  'ksE17R2SfFM',
#  'OJF3CjVxEVk',
#  'UcKtBSlfpRU',
#  '-hU1O3bG1eo',
#  'V8BTsiMxyaQ',
#  'Vv7mpVPvab4',
#  '97axrS3Npxk',
#  'ir9ZyTXbNIs',
#  '0QTV0RAfHho',
#  'uXEiWgnzSKU',
#  'm99Py_8NtZE',
#  'epr4YZrlQkQ',
#  'dQ4knokHgxY',
#  '308kgzwY5D4',
#  'bw2439YkLUM',
#  '0HCdaWzNzWU',
#  'TGTjYk4xyCc',
#  'EGxVQdzhRKk',
#  'QK3fFUPnu-o',
#  'ttjsXunEK80',
#  '4EdrD3Aee_M',
#  '8n7FywUNrEY',
#  'XPEbdkLqK8M',
#  'epr4YZrlQkQ',
#  'Gz1Hhcasz8U',
#  'I6bRg5gSR-4',
#  'BzzodFHR2rc',
#  'rSaMU5rypME',
#  'I37oZyzdm3o',
#  'abAhYynfJ9I',
#  'EGmKVkuamog',
#  'pBNkBfJPK5s',
#  'kn7lNk_OWl0',
#  'rUM83f8KL4Y',
#  'DO4azcPQEs4',
#  '806g5vUgdZo',
#  'dZ1fCkoNQS8',
#  'y2jqENUqOZA',
#  'Exps12ZtGQo',
#  'rUM83f8KL4Y',
#  'DO4azcPQEs4',
#  '806g5vUgdZo',
#  'dZ1fCkoNQS8',
#  'y2jqENUqOZA',
#  'Exps12ZtGQo',
#  'JaqCpNMzi-g',
#  'XrG2yLRi1HA',
#  'OpURIEvLUFI',
#  '3eLpyTyyNOE',
#  '6s0ITBxlapg',
#  'l0FEWgx6oEA',
#  'PX_Xp6yZYgk',
#  'PGPas41xzO0',
#  'Y8oHFymcU0s',
#  '2ZhwNot1QQc',
#  'Ux6q6e7NeRk',
#  'cc2fP_2xMFw',
#  'VcFdyCb9zu8',
#  'pEFHUrT-qaM',
#  'Tcl9DpF-xE8',
#  'ieB8Te7ZfNA',
#  '0_hBPouE-jY',
#  'ZaDM1p742EY',
#  'PcaBJZkGx_U',
#  '3LmjBbP-e8U',
#  'YKiMrg6rgYQ',
#  '-hU1O3bG1eo',
#  'PQ9PaRuwxek',
#  'eZMH6Mo0f9A',
#  'HxIct0i-CcA',
#  'pd3eV-SG23E',
#  '1xvQFNDwQzs',
#  'P1DojnvnQAs',
#  'Fn7NLWHJw4s',
#  'OJF3CjVxEVk',
#  'lUCa4e5Mkrc',
#  '8nQpO6gbV94',
#  'tnPotffUTuk',
#  'ksE17R2SfFM',
#  'UJcCILRpzf4',
#  'JJyc5JaRVUA',
#  '8Jg8KoyCHwM',
#  '-Pw6sYwhDeQ',
#  '8nQpO6gbV94',
#  'THNG8shwApo',
#  'xeDeq--YUUU',
#  'LVVA6w0eYpE',
#  'AkIlAQMf7HU',
#  'PcTLhtvxHNg',
#  'tnPotffUTuk',
#  'kBVRxx-h-Ks',
#  'FBnn-NzkoK0',
#  'F3A0AkySYKk',
#  'ZaDM1p742EY',
#  'HFNLv_GPB9c',
#  'ffQ9A0O4uL4',
#  'T-Xk_xirUlo',
#  'dpqW1bZBPbI',
#  'PQYZnlexna0',
#  'VTJnIuJcFIs',
#  'ABWCfeckF8s',
#  'yOafa0PzFa8',
#  'zHjVS9u9K4Q',
#  'bKrR20WfD4c',
#  'yOafa0PzFa8',
#  'PFHq9htJN-I',
#  'C7yQeUTpFl4',
#  'iDkvBrSZ0yQ',
#  '8Dr596urRZg',
#  '58r5sXxBuEg',
#  'Jl4ssMnFsy0',
#  'YMA4mFMmc3U',
#  'Upeu2BCPLJA',
#  'rJ5bK-v6MOQ',
#  'C-AGoK2zaLw',
#  'ksE17R2SfFM',
#  'UJcCILRpzf4',
#  'JJyc5JaRVUA',
#  '8Jg8KoyCHwM',
#  '8nQpO6gbV94',
#  'xeDeq--YUUU',
#  '-Pw6sYwhDeQ',
#  'THNG8shwApo',
#  '1GCONcr-jzc',
#  'E4YnK9g5L_c',
#  'K34kkgPN_Ys',
#  '4j6jumGlYx8',
#  '1ByfLn6eVZY',
#  'Jv3zvWZlXkk',
#  'oBp8WrTxn_w',
#  '9tU9oGGc9ac',
#  'E1xrBs_BZgs',
#  'uMSr4XXfKO8',
#  'ElGBcoSurLY',
#  't5EiR5txpJU',
#  '-hU1O3bG1eo',
#  'u0bcXim2m4M',
#  '3LmjBbP-e8U',
#  'LokvcieQpjw',
#  'lUCa4e5Mkrc',
#  'HxIct0i-CcA',
#  'PcaBJZkGx_U',
#  'P1DojnvnQAs',
#  'YKiMrg6rgYQ',
#  'OJF3CjVxEVk',
#  'pd3eV-SG23E',
#  'eZMH6Mo0f9A',
#  'Fn7NLWHJw4s',
#  'PQ9PaRuwxek',
#  '1xvQFNDwQzs',
#  'Fn7NLWHJw4s',
#  'Fn7NLWHJw4s',
#  'Fn7NLWHJw4s',
#  'Fn7NLWHJw4s',
#  'Fn7NLWHJw4s',
#  'Fn7NLWHJw4s',
#  'Fn7NLWHJw4s',
#  'Fn7NLWHJw4s',
#  '1xvQFNDwQzs',
#  '3ZQuSCjSink',
#  'IlcwfaQ2Cs4',
#  '8QoxErNRlTo',
#  'oRauaQO50IY',
#  'c4ZzLrCJpRw',
#  'rHeICF7nAZE',
#  'naETaUlzK0E',
#  'uXEiWgnzSKU',
#  'dTwrFRfNjzA',
#  'AHeHF9Bz458',
#  'IWmpE9axp10',
#  'pX-0uqaiVC4',
#  'Mr1YcYfZuuU',
#  'g3Yyn9VQafE',
#  '2U9nakXsKaY',
#  'soLNRrF-huk',
#  '4Y_mVGbsKoM',
#  'uSCA0DHRCqw',
#  'OG5yCHnipdM',
#  'd3IQo9NgTtI',
#  't3yfr2LBvrw',
#  'd3IQo9NgTtI',
#  'M4P-ru_SE9s',
#  '_FCnnvrHQsc',
#  'DB_3jUmJh3U',
#  'yrkNv9DHN7w',
#  'jbPSsSND4nk',
#  'Fj_9Xwtx_2s',
#  'MVtEh2Td_Bw',
#  'B75sjJaYRsQ',
#  'Nd833w04DWA',
#  '6dyiTf9kHDg',
#  'UgWwCeICLYc',
#  'P29WUd4q6kE',
#  '5ikd6vpcq8Q',
#  '3wrto8oJu5A',
#  'mpizq0NZF7s',
#  '38lcQsEMGrk',
#  '7wvNwOPprBE',
#  'Oc_VUUE9MHo',
#  'aVmZpcrQBU4',
#  'LWmVK8K2QhM',
#  'qX2GsMj7154',
#  'rBCmeVLHrZ4',
#  '9Y15es8OY0U',
#  'DDs5bXh4erM',
#  'RTUwaCImChM',
#  '0QTV0RAfHho',
#  '88m2XdyGXRY',
#  '97axrS3Npxk',
#  'V8BTsiMxyaQ',
#  '83I_5lq5MwI',
#  'xWTiOqJqkk0',
#  'CqlnZuXQpy8',
#  'QKb30DgwZ7Y',
#  'hiKYufVEUtI',
#  'jGqpz3stgzY',
#  'kz6fybUvGJM',
#  'BkTqW9ohMTM',
#  'IBT0_3QUy98',
#  'nU4jIUZF_AI',
#  'dIdd22MfJVI',
#  'fgWLAYFv9G0',
#  'ysWcr5X0KZs',
#  'mDCmj_w9pPk',
#  'CfYG8Q3ZpMA',
#  '8yvWJ6nq_HE',
#  'T-XFIPKmhww',
#  'V46K7apDziA',
#  'LygMIq09Cps',
#  'aYSvA_SR90g',
#  'rVEMTxg_LrU',
#  'GtDRcXtDg-4',
#  'amv7CzCmHU0',
#  'FdjR-AMz50c',
#  'w0hirWu9D70',
#  'Wsvx-t1qFpI',
#  'BfwbO0f1R8o',
#  'qIAFyPYlq_U',
#  'VZik4B5LhrM',
#  'x1FP3j07vp8',
#  'eNhq2aJaD2w',
#  'nObHir-s-44',
#  'EIvVBG71ZYg',
#  '6dwbkrAKpvY',
#  'ir9ZyTXbNIs',
#  'FPNODXJMDVg',
#  'rvFbac6ds9M',
#  'Cno3CFgajmQ',
#  'eVPsNWD90lY',
#  '0QTV0RAfHho',
#  'Wsvx-t1qFpI',
#  'kz6fybUvGJM',
#  'FCpyn7ojWlw',
#  'nObHir-s-44',
#  'DGOhgHRRufU',
#  'ByI-spTmFLQ',
#  'dIdd22MfJVI',
#  'Oc_VUUE9MHo',
#  'rBCmeVLHrZ4',
#  '-u4xfduhrrA',
#  'iCVb6_JS4RU',
#  'x1FP3j07vp8',
#  '1Pp3mQmgexg',
#  'YKOfHBb5CWM',
#  '6j4vxu8dnp4',
#  'JWSRqWpWPzE',
#  'UjZqcDYbvAE',
#  'Hh9yZWeTmVM',
#  'tcBBNB5JTOQ',
#  'UabLD-3jETQ',
#  'EPjddml1Td4',
#  '-rpSfk-AKGs',
#  'f9DAg7bo6Lw',
#  'tM3Qq_UjxIA',
#  '_W_sf0q7mA8',
#  'C2a4lI5242M',
#  'ZZ_r4tZFUBY',
#  'ztFNbpasg-c',
#  'XRGFYNHXmJE',
#  'TxemOZuhpXI',
#  '31XJgZtsFhU',
#  'TMChCThZp_Y',
#  'X_jRbUgJ0m8',
#  'r5XeWyhgpCY',
#  'wMwW6T9V6A4',
#  'fVp5rCJTzBI',
#  '0JIAi810iZo',
#  'SQxCtWMFALo',
#  'ClCBXMFYjak',
#  'T-XFIPKmhww',
#  '7wvNwOPprBE',
#  'QKb30DgwZ7Y',
#  'CqlnZuXQpy8',
#  '8yvWJ6nq_HE',
#  'UdqMU9IJLW4',
#  'BcY75hwb_Ls',
#  'z-_wh3kpTU0',
#  'DBKkAL49lX0',
#  'X08lyEBG11g',
#  'yybtW6tSLeM',
#  'DLrvUjY0haE',
#  'NJ46EvQK_8E',
#  'lDVqEaVN89g',
#  'ngC4nOlwneE',
#  '76UjJPmtD3U',
#  '554SklLwYxc',
#  '68l9-7zGf9w',
#  'B1xtAuFNtCc',
#  'CD484TbC6r8',
#  'C5hqc5FhOPM',
#  'tS0BM4DbJyo',
#  'IOKABU9zvf8',
#  'gxBSkeWmkbE',
#  'rTfjqrcyI9c',
#  'bVpa7tZDGOk',
#  'ghpGuXUxHb8',
#  'SCE40sLBx-s',
#  'o8zJf1bJoH8',
#  '7TmcbZ4FxSw',
#  'HT41E_r9vNQ',
#  'gwGP6gj823o',
#  'TJxsRqmS_6o',
#  'i9Tg7zi3tnE',
#  '9oG_B2hNuqk',
#  'RpsjmgivjmA',
#  'jpsyk-5jGwY',
#  'EnTAv6NKsE4',
#  'GtDRcXtDg-4',
#  'nWb_X3ZJQjw',
#  'hr8jWDyb1jg',
#  '38lcQsEMGrk',
#  'Qd9YGu3FWgc',
#  'QKkQU4lzIbc',
#  '4eGK5Q25Hpk',
#  'crc0JH42Lwk',
#  'xy-BqLWpoQM',
#  'Eso_PkuYlB4',
#  'hwe411J3Hbc',
#  'IBT0_3QUy98',
#  'eZxkpvoJI2Q',
#  '6dwbkrAKpvY',
#  '0sDtXpMUKAE',
#  '6n8AitBL7xc',
#  '45mI3RaNOow',
#  '3Q__2oA69PM',
#  'guwcn8XWCBI',
#  'GxHIGioBZ10',
#  '8a8XWsxX2Po',
#  'IhK0xTkA2W0',
#  'OAqmbqgybos',
#  'nI3ujBtHSBA',
#  'xR8pyhOjf8Y',
#  'vjmFNHqqTF0',
#  '-u4xfduhrrA',
#  'rNS6MoUCWqg',
#  'QtopFGAPjrc',
#  '25yj96eOvp4',
#  'Oc_VUUE9MHo',
#  'rBCmeVLHrZ4',
#  '0QTV0RAfHho',
#  'x1FP3j07vp8',
#  'Kyq5OwloANw',
#  'UM8mEOKooDQ',
#  'JaEIz7ep_Tc',
#  'xCl_k0puoUI',
#  'cqSJoRAP9SA',
#  '_ULXuUjVYRw',
#  '4qqW8po12Nw',
#  'NbA-DYugdTI',
#  'z9bqOGnria0',
#  '9Y15es8OY0U',
#  'mDCmj_w9pPk',
#  'LWmVK8K2QhM',
#  'dTwrFRfNjzA',
#  'AHeHF9Bz458',
#  'IWmpE9axp10',
#  'uXEiWgnzSKU',
#  '2210F8waz1M',
#  'T5FSqr8DViQ',
#  'rHeICF7nAZE',
#  'naETaUlzK0E',
#  'BnPx-4SuutI',
#  'xgVXzi6Ve6s',
#  'Mziur7NLs80',
#  'Mziur7NLs80',
#  'xbdRQkZhj60',
#  'OfbmsAup-NU',
#  'nwGSLJBdPPM',
#  'omhHleLTgAU',
#  '4S37C8X3-RU',
#  'QRjFD1dQcs4',
#  'GCTDFH4o56g',
#  'uvVt-vDF5_w',
#  'hhDAPwWuGE0',
#  'LDcRUh84tuM',
#  '9x7nRPh-yvc',
#  'u7qBBwDmmN4',
#  'l7G1V8OIq0A',
#  'IGs_GQSh4cY',
#  'XaCDQqVFLPs',
#  'YrNF4IaycGM',
#  'ir18zD4fMW4',
#  'c9FHH0vI6pc',
#  'iczGMxfCwks',
#  'C3MJeBsMqWU',
#  'Xm2bEd6NoCQ',
#  'UXsPSKDCdqA',
#  'kAO_AEy1xG4',
#  '9ntdLHXj50M',
#  'Rb8gjCg3Oac',
#  'HUUZ2QynhMY',
#  'aErwuEJ_3z8',
#  '0W7TEGviucY',
#  'pgU8rRi3lNM',
#  'XibJW9p3bNU',
#  'Em8wKSVrQSs',
#  'c3mjH_TwRFc',
#  '_XYcCNY-ass',
#  'OZOS0yc0-Pw',
#  'dJG0n1Wj2Fs',
#  '2P5h88eh0_M',
#  'RP9w0s4r4kw',
#  'Oc_VUUE9MHo',
#  'z-_wh3kpTU0',
#  'VXZ1WcQQJAQ',
#  'tfDlcZpEApo',
#  'zxsA50SrLpg',
#  'rVEMTxg_LrU',
#  'Y0D_4LjCIck',
#  '0ujpslmMbZc',
#  'JaqCpNMzi-g',
#  'fBwXrJ8X8rs',
#  '83I_5lq5MwI',
#  'z-_wh3kpTU0',
#  'XrG2yLRi1HA',
#  'IQN2vlPFweY',
#  'aNPssnaOtAc',
#  'sGsCc34EgeI',
#  'Qiz9msSrR3s',
#  'D_QgHZOU1u0',
#  'KhBHEqyv-sU',
#  'rBCmeVLHrZ4',
#  'Oc_VUUE9MHo',
#  '1OKtkO_K608',
#  '35fRZsYNyvU',
#  'ClCBXMFYjak',
#  'SQxCtWMFALo',
#  'Mziur7NLs80',
#  'S1qF9iBbf3E',
#  'aZVa4gnAjFA',
#  'RP9w0s4r4kw',
#  'spMRRwAPopI',
#  'NTokrubxoVQ',
#  'Ut722QINibo',
#  'Z5WBY6IXYHg',
#  'jpsyk-5jGwY',
#  'EnTAv6NKsE4',
#  'oDqWPLRIMdY',
#  'dJG0n1Wj2Fs',
#  'tfDlcZpEApo',
#  'OZOS0yc0-Pw',
#  'PrAzj-daB9s',
#  'UM8mEOKooDQ',
#  'vjmFNHqqTF0',
#  'xR8pyhOjf8Y',
#  'nI3ujBtHSBA',
#  'nwGSLJBdPPM',
#  'omhHleLTgAU',
#  'WEO4f_4lPYs',
#  'juplR0zhJaU',
#  'tLo6x8NDqNs',
#  'OZTk80FwHYU',
#  'HjoEbCAaaIc',
#  '83I_5lq5MwI',
#  '2kNtnTYhQdA',
#  'U4EInflwYc8',
#  'C56bsd7hxfY',
#  'mb5tBUAzmjA',
#  'E4gx25UAZiU',
#  'z-_wh3kpTU0',
#  'XrG2yLRi1HA',
#  'IQN2vlPFweY',
#  'sGsCc34EgeI',
#  'KhBHEqyv-sU',
#  'D_QgHZOU1u0',
#  'Qiz9msSrR3s',
#  'U4EInflwYc8',
#  'dXTi1ivKKdo',
#  'E4gx25UAZiU',
#  'C56bsd7hxfY',
#  'mb5tBUAzmjA',
#  '-e3GYlvHRLE',
#  'LhewxyNSIO0',
#  'or42k9UZCZY',
#  '2Cj2LdB0jV0',
#  'Fdz7R5b1SvU',
#  'BnHgz0MvbYk',
#  '-dHHkLz8tjc',
#  '1EZlR2m8hLM',
#  'mXG58_3r5vg',
#  'tMBuoA9LRvU',
#  'UOaPBQM1lf0',
#  'exNBIoc7T2M',
#  '_905KK9A48Q',
#  'r8Yqq5f5f5M',
#  'PqFiNT1OA18',
#  'Fi_nUa-f6Jc',
#  'q3_vLc3-Fys',
#  '95TLJ-rHD-U',
#  'Gqqf_PpKR_I',
#  'rM7_w-Rs01Y',
#  'PrnploVsjBI',
#  'igzeQxN4efc',
#  'MRqwr8Zzqcs',
#  'H6y5XLFIfiE',
#  '3bnyflp-IQw',
#  'OAcBBIa26SA',
#  'Pn0JH6bTMSg',
#  'z9eIco0juTY',
#  '9BByAxgUCJw',
#  'fZILR8EvFUQ',
#  'RhfUGpEp9to',
#  'CR_JvOHcN5E',
#  'YoYhkdTeUZ0',
#  '4leQboIUaYs',
#  'NnfBpCQlZ6o',
#  'WXM-5tybbDw',
#  'dRsjsHK_CnE',
#  'eFGDORhspsc',
#  'VlFfovdtaXg',
#  'J1b7fn_S0i4',
#  'eL_-V7WM8MU',
#  'WsAwDBG6Kk8',
#  'uk_4xss8yNU',
#  'W1zRMunFc4Q',
#  'OPkqtboFFYI',
#  'AkBKzjlCNX0',
#  'FJMZDqO3yNg',
#  'e-9TcF1Oyi4',
#  'fJR2dKxGfeM',
#  'yLcp0sTJVuQ',
#  'lGF2QrDLXCM',
#  '0Z7zdznLk4Q',
#  'lo26HlAykA8',
#  'ObSPLQ-1fJI',
#  'GUIMi_WoSc4',
#  'jPu3u8kfxCw',
#  '0Z7zdznLk4Q',
#  '644KT41mahg',
#  'fJR2dKxGfeM',
#  'lo26HlAykA8',
#  '6L_173gzmsc',
#  'NtvvmW_6PP8',
#  'vMieXIDC-Dg',
#  'YspEQ7pIV0E',
#  'zMRZ67lO84Q',
#  'CgAJAmP14kQ',
#  'Ik4ixPWCrrA',
#  'W1zRMunFc4Q',
#  '8ni_lEqrLX4',
#  'TTDi5bPybfo',
#  'jPu3u8kfxCw',
#  '5pVtU0c_zr8',
#  'lGF2QrDLXCM',
#  'QNdAUowfGJ4',
#  'Mxdgh6M0mPQ',
#  'R8wPDkamVb0',
#  ...]

# %%
# 影片評價
url = 'https://www.googleapis.com/youtube/v3/videos'

def get_video_data(vid) :
    parameters = {
        'part':'snippet,contentDetails,statistics', 
        'id':vid,                                  # 影片id，也可以＆連接多個id
        'key': apikey,
    }
    page = requests.request(method='get', url=url, params=parameters)
    js = json.loads(page.text)
    
    if not js.get('items'):                        # 若影片刪除或下架，則跳過這筆
        return
    
    else:
        js0 = js['items'][0]['contentDetails']
        js1 = js['items'][0]['statistics']
        js2 = js['items'][0]['snippet']

                                                   # 文字資料
        vd = [js['items'][0]['id']]
        vd.append(js2['categoryId'])
        vd.append(js2['channelTitle'])
        vd.append(js2['title'])
        vd.append(js2['description'])
        vd.append(js2['publishedAt'])
        vd.append(js0['duration'])
        
                                                   # 數值資料，若查無數據，則回傳值為0
        if js1.get('dislikeCount'):
            vd.append(js1['dislikeCount'])  
        else:
            vd.append(0)
            
        if js1.get('likeCount'):
            vd.append(js1['likeCount'])  
        else:
            vd.append(0)
            
        if js1.get('favoriteCount'):
            vd.append(js1['favoriteCount'])  
        else:
            vd.append(0)
            
        if js1.get('viewCount'):
            vd.append(js1['viewCount'])  
        else:
            vd.append(0)
            
        # tags
        
        return vd                                  # 回傳array

# %%
# 以videoid清單，爬出各影片資料
# Array轉成Set排除重覆值
# Set轉成DataFrame

df_vd = pd.DataFrame()
set_video = set(videoid)                           # 排重

for vid in range(len(set_video)) :
    df_vd = df_vd.append( [get_video_data(videoid[vid])], ignore_index=True)

# %%
# 設定欄位名稱
col={0:'video_id',1:'category',2:'channel_name',3:'video_title',4:'description',5:'publishedAt',
         6:'duration',7:'dislike',8:'like',9:'favorite',10:'viewcount'}
df_vd = df_vd.rename(columns=col)

# %%
# 輸出成csv檔，檔名「video(日期)_statistics_(排名).csv」
today = str(dt.datetime.today()).split()[0]
filename = 'video_statistics%s_%d-%d.csv' % (today, m, n)
df_vd.to_csv(filename)
