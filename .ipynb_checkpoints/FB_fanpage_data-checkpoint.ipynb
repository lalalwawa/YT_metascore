# %% [markdown]
# # FB Graphic API 粉絲團統計數據爬蟲
# #### 第一部份：取粉絲團基本資料
# #### 第二部份：取貼文的統計
# #### 先安裝pip3 install requests

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# ## 第一部份：抓取粉絲團基本資料

# %%
# 貼上FB API Token
# 簡單測試token是否有通
token = 'EAACEdEose0cBAKs50ZAOFSBRo6bRy7aS2fviPsxwwAjPXyWZCGfjQHhyNNzhtJOZB7i5prHRufOyMzH0aY3P72UNZBi7czZBkyKClV22pQb2Cls6wtKudqSBYxek01EOez6mh3AsnZCo8Oyr3ZC8ZCYjgDlwAfCjzVCC8ZAVsZCmkcuMEwfVkJtbuhBWNMQzm40nWSLYZCbG4yIfQZDZD'
res = requests.get("https://graph.facebook.com/v2.11/me?access_token=%s" % (token))
print(res.text)
# Out:
# {"name":"Alicia Lee","id":"844389662238733"}

# %%
# 提取基本資料

# 目標粉絲團縮名，在array中給予縮名的清單
pages = ['BaiChiGongZhu']

# 開始提取粉絲頁基本資料
for page in pages:
    info = '?fields=id,name,about,category,likes,link,talking_about_count,website'
    res = requests.get('https://graph.facebook.com/%s%s&access_token=%s' % (page, info, token))
    #print(res.text)
    #json.loads(res.text)['id']

    
    pg1 = [page,                         # 縮名，string
      json.loads(res.text)['id'],        # 唯一碼，numeric
      json.loads(res.text)['name'],      # 粉專名稱，string
      json.loads(res.text)['likes'],     # 粉絲數，numeric
      json.loads(res.text)['talking_about_count'],   # 討論數，numeric
      json.loads(res.text)['category'],  # 分類，string
      json.loads(res.text)['about']      # 介紹，string
          ]

# %%
# 轉成DataFrame
df = pd.DataFrame([pg1])

# %%
# 為dataframe欄位命名
df = df.rename(columns={0:'PID',1:'ID',2:'NAME',3:'LIKES',4:'TALKA',5:'TYPE',6:'ABOUT'})

# %%
# 增加一row到dataframe中
df = df.append([pg1], ignore_index=True)
# Out:
# /anaconda/lib/python3.6/site-packages/pandas/core/indexes/api.py:77: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)

# %%
df
# Out:
#              PID               ID       NAME      LIKES      TALKA      TYPE  \
# 0  BaiChiGongZhu  363734540324168       白癡公主  1011428.0    26513.0  Producer
# 1         test01    9187298370419  beautiful   128793.0  1987239.0      test
# 2            NaN              NaN        NaN        NaN        NaN       NaN
# 3            NaN              NaN        NaN        NaN        NaN       NaN
#
#                          ABOUT              0                1          2  \
# 0  舒服合作信箱87gongzhu@gmail.com\n            NaN              NaN        NaN
# 1               test test test            NaN              NaN        NaN
# 2                          NaN  BaiChiGongZhu  363734540324168       白癡公主
# 3                          NaN         test01    9187298370419  beautiful
#
#            3          4         5                            6
# 0        NaN        NaN       NaN                          NaN
# 1        NaN        NaN       NaN                          NaN
# 2  1011428.0    26513.0  Producer  舒服合作信箱87gongzhu@gmail.com\n
# 3   128793.0  1987239.0      test               test test test

# %% [markdown]
# ## 第二部份：取貼文的統計

# %%
# 先創一個空的DataFrame
#feed = [x for x in range(13)]
df_article = pd.DataFrame()

# %%
# 粉絲團縮名
pages = ['BaiChiGongZhu']


# 近兩週貼文基本統計
for page in pages:
    info = '?fields=feed{from, id, type, created_time, message, source, shares}'
    period = '&since=1513296000&until=1514678400'            # 近兩週，2017/12/15-12/30
    res = requests.get('https://graph.facebook.com/%s%s%s&access_token=%s' % (page, info, period, token))
    
    
    for i in range(0,len(json.loads(res.text)['feed']['data'])):
        js1 = json.loads(res.text)['feed']['data'][0]

        feed = [page,                                      # 粉專縮名
               js1['from']['name'],       # 粉專名稱
               js1['id'],                 # 文章唯一碼
               js1['type'],               # 文章類型
               js1['created_time'],       # 貼文時間
               js1['message'],            # 貼文內容
               js1['source'],             # 貼文內容的外部來源
               js1['shares']['count'] ]   # shares


        sid = js1['id']
        likes = '?fields=likes.limit(0).summary(total_count)'
        res2 = requests.get('https://graph.facebook.com/%s%s&access_token=%s' % (sid, likes, token))
        react = '?fields=reactions.type(LOVE).limit(0).summary(total_count).as(reactions_love),reactions.type(WOW).limit(0).summary(total_count).as(reactions_wow),reactions.type(HAHA).limit(0).summary(total_count).as(reactions_haha),reactions.type(SAD).limit(0).summary(total_count).as(reactions_sad),reactions.type(ANGRY).limit(0).summary(total_count).as(reactions_angry)'
        res3 = requests.get('https://graph.facebook.com/v2.11/%s%s&access_token=%s' % (sid, react, token))

        feed.append(json.loads(res2.text)['likes']['summary']['total_count'])      # 讚

        feed.append(json.loads(res3.text)['reactions_love']['summary']['total_count'])    # reaction_love
        feed.append(json.loads(res3.text)['reactions_haha']['summary']['total_count'])     # reaction_haha
        feed.append(json.loads(res3.text)['reactions_sad']['summary']['total_count'])      # reaction_sad
        feed.append(json.loads(res3.text)['reactions_wow']['summary']['total_count'])      # reaction_wow
        feed.append(json.loads(res3.text)['reactions_angry']['summary']['total_count'])    # reaction_angry
        
        # 增加一row到dataframe中
        df_article = df_article.append([feed], ignore_index=True)

# %%
# 為文章dataframe命名
df_article = df_article.rename(columns={0:'PID',1:'NAME',2:'SID',3:'TYPE',4:'CREATE_TIME',5:'MESSAGE',6:'SOURCE',7:'SHARES',8:'LIKES',9:'LOVE',10:'HAHA',11:'SAD',12:'WOW',13:'ANGRY'})
# show
df_article
# Out:
#               PID  NAME                               SID   TYPE  \
# 0   BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 1   BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 2   BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 3   BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 4   BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 5   BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 6   BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 7   BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 8   BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 9   BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 10  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 11  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 12  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 13  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 14  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 15  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 16  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 17  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 18  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 19  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 20  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 21  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 22  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 23  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
# 24  BaiChiGongZhu  白癡公主  363734540324168_1775153095848965  video
#
#                  CREATE_TIME  \
# 0   2018-01-01T15:32:45+0000
# 1   2018-01-01T15:32:45+0000
# 2   2018-01-01T15:32:45+0000
# 3   2018-01-01T15:32:45+0000
# 4   2018-01-01T15:32:45+0000
# 5   2018-01-01T15:32:45+0000
# 6   2018-01-01T15:32:45+0000
# 7   2018-01-01T15:32:45+0000
# 8   2018-01-01T15:32:45+0000
# 9   2018-01-01T15:32:45+0000
# 10  2018-01-01T15:32:45+0000
# 11  2018-01-01T15:32:45+0000
# 12  2018-01-01T15:32:45+0000
# 13  2018-01-01T15:32:45+0000
# 14  2018-01-01T15:32:45+0000
# 15  2018-01-01T15:32:45+0000
# 16  2018-01-01T15:32:45+0000
# 17  2018-01-01T15:32:45+0000
# 18  2018-01-01T15:32:45+0000
# 19  2018-01-01T15:32:45+0000
# 20  2018-01-01T15:32:45+0000
# 21  2018-01-01T15:32:45+0000
# 22  2018-01-01T15:32:45+0000
# 23  2018-01-01T15:32:45+0000
# 24  2018-01-01T15:32:45+0000
#
#                                               MESSAGE  \
# 0   2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 1   2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 2   2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 3   2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 4   2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 5   2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 6   2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 7   2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 8   2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 9   2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 10  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 11  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 12  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 13  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 14  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 15  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 16  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 17  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 18  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 19  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 20  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 21  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 22  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 23  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
# 24  2017痴痴的人生跑馬燈完整版：https://picsee.pro/v-2896031\n...
#
#                                                SOURCE  SHARES  LIKES  LOVE  \
# 0   https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 1   https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 2   https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 3   https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 4   https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 5   https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 6   https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 7   https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 8   https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 9   https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 10  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 11  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 12  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 13  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 14  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 15  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 16  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 17  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2360    53
# 18  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2361    53
# 19  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2361    53
# 20  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2361    53
# 21  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2361    53
# 22  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2361    53
# 23  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2361    53
# 24  https://www.youtube.com/embed/5z3hvyNljd4?list...      10   2361    53
#
#     HAHA  SAD  WOW  ANGRY
# 0    106    0    2      0
# 1    106    0    2      0
# 2    106    0    2      0
# 3    106    0    2      0
# 4    106    0    2      0
# 5    106    0    2      0
# 6    106    0    2      0
# 7    106    0    2      0
# 8    106    0    2      0
# 9    106    0    2      0
# 10   106    0    2      0
# 11   106    0    2      0
# 12   106    0    2      0
# 13   106    0    2      0
# 14   106    0    2      0
# 15   106    0    2      0
# 16   106    0    2      0
# 17   106    0    2      0
# 18   106    0    2      0
# 19   106    0    2      0
# 20   106    0    2      0
# 21   106    0    2      0
# 22   106    0    2      0
# 23   106    0    2      0
# 24   106    0    2      0

# %% [markdown]
# # 以下是FB API fanpage相關參數
# ### 參考用，非正式語法

# %%
# 測試ID 
page = 'BaiChiGongZhu'
#page = 'teemomustdie'
#page = '168161663222590'

# 只算LIKE數
#commend = '/feed?fields=message,likes.limit(1).summary(true)'
# 某段時間內的貼文
#commend = '/feed?fields=message,likes.limit(1),created_time&until=1514462400&since=1513771200&limit=100'
# 粉絲團基本資料
commend = '?fields=id,name,about,category,likes,link,talking_about_count,website'
df = df.rename(columns={0:'PID',1:'ID',2:'NAME',3:'LIKES',4:'TALKA',5:'TYPE',6:'ABOUT'})
res = requests.get("https://graph.facebook.com/%s%s&access_token=%s" %(page, commend, token))
print(res.text)
# Out:
# {"id":"363734540324168","name":"\u767d\u7661\u516c\u4e3b","about":"\u8212\u670d\u5408\u4f5c\u4fe1\u7bb187gongzhu\u0040gmail.com\n","category":"Producer","likes":1010895,"link":"https:\/\/www.facebook.com\/BaiChiGongZhu\/","talking_about_count":18458,"website":"http:\/\/pics.ee\/87yt"}

# %%
# 粉絲數
commend = '?fields=fan_count'
# 粉絲頁縮名
commend = '?fields=page_token'

# %%
# 近十篇貼文
commend = 'BaiChiGongZhu?fields=feed.limit(10)'
# 貼文分享自其他來源 {parenet_id}
commend = 'BaiChiGongZhu?fields=feed.limit(10){parent_id}'

# 貼文的ID {id}
# 貼文中tag其他人 {message_tags}
# 貼文中影片的名稱 {name}
# 貼文類型 {icon}  | /icon/post.gif 一般貼文(可能附有照片或影片連結或新聞連結) | /icon/video.gif 影片貼文 | NA 分享貼文
# 貼文類型 {status_type} | added_photos | added_video | mobile_status_update | shared_story |
# 貼文類型 {type} | photo | video | link |
# 原貼文的內容文字 {description} 如果是分享自其他來源就會是原貼文的文字
# 粉絲團貼文內容 {message} 分享的貼文，附加的文字說明在此
# 貼文時間 {created_time}
# 貼文唯一碼 {created_time}
# 哪個粉絲團的貼文 {from} 查單一粉絲團時用不到
# 貼文的預設靜態圖 {full_picture}
# 貼文的導向連結 {link} 可以是內部或外部
# 貼文內容的外部來源 {source}
# 分享次數 {shares}
# 最後加上時間區間 &since=1480849200&until=1480856400  使用timestamp

# %%
# 某貼文的互動數，所有reaction
commend = '363734540324168_1763402230357385?fields=reactions.type(LOVE).limit(0).summary(total_count).as(reactions_love),reactions.type(WOW).limit(0).summary(total_count).as(reactions_wow),reactions.type(HAHA).limit(0).summary(total_count).as(reactions_haha),reactions.type(SAD).limit(0).summary(total_count).as(reactions_sad),reactions.type(ANGRY).limit(0).summary(total_count).as(reactions_angry)'
# 文章觀看數 ?fields=seen 沒有權限
# 文章分析  ?fields=insights 沒有權限
